# %%
# %%time
import pandas as pd
# Out:
# Wall time: 5.49 s

# %%
# %%time
import numpy as np
# Out:
# Wall time: 0 ns

# %%
# %%time
import matplotlib.pyplot as plt
# Out:
# Wall time: 3.2 s

# %%
# %%time
import seaborn as sns
# Out:
# Wall time: 5.39 s

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 28BB-24A5
#
#  Directory of C:\Users\user\Documents\jupyter assignments\Assignments
#
# 07/06/2021  04:54 PM    <DIR>          .
# 07/06/2021  04:54 PM    <DIR>          ..
# 07/05/2021  05:57 PM    <DIR>          .ipynb_checkpoints
# 05/26/2021  06:13 AM    <DIR>          ADS-Assignment-1
# 05/23/2021  08:41 PM             5,669 alumni.csv
# 07/05/2021  03:55 PM            22,836 Data Analysis Break down.ipynb
# 07/05/2021  03:58 PM           196,234 Data Analysis Visualization.ipynb
# 07/06/2021  04:54 PM         3,997,927 Data Visualization With Plotly.ipynb
# 06/07/2021  07:21 PM            81,601 Matplot assignment.ipynb
# 05/23/2021  08:25 PM            29,448 NumPy Assignment.ipynb
# 06/05/2021  09:16 PM            88,614 Pandas Assignments.ipynb
# 06/01/2021  12:38 PM            27,984 Practical.ipynb
# 07/06/2021  03:19 PM            31,199 SciKit Learn.ipynb
# 07/05/2021  06:28 PM         3,560,907 Test.csv
# ...

# %%
Emp_attr = pd.read_csv('/Users/user/Documents/jupyter assignments/ADS-Assignment-2-3/WA_Fn-UseC_-HR-Employee-Attrition.csv')

# %%
Emp_attr.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %% [markdown]
# ###  Show a breakdown of distance from home by job role and attrition.

# %%
Emp_attr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
Emp_attr.loc[:,['Attrition','JobRole','DistanceFromHome']]
# Out:
#      Attrition                    JobRole  DistanceFromHome
# 0          Yes            Sales Executive                 1
# 1           No         Research Scientist                 8
# 2          Yes      Laboratory Technician                 2
# 3           No         Research Scientist                 3
# 4           No      Laboratory Technician                 2
# ...        ...                        ...               ...
# 1465        No      Laboratory Technician                23
# 1466        No  Healthcare Representative                 6
# 1467        No     Manufacturing Director                 4
# 1468        No            Sales Executive                 2
# 1469        No      Laboratory Technician                 8
#
# [1470 rows x 3 columns]

# %%
plt.figure(figsize =(10, 9))
sns.violinplot(data=Emp_attr, y="JobRole",
               x="DistanceFromHome", hue="Attrition",
               palette="Set2", slit="true").set(title = 'breakdown of distance from home by job role and attrition')
# Out:
# [Text(0.5, 1.0, 'breakdown of distance from home by job role and attrition')]

# %% [markdown]
# ### Compare average monthly income by education and attrition

# %%
Emp_attr.loc[:,['MonthlyIncome','Education','Attrition']]
# Out:
#       MonthlyIncome  Education Attrition
# 0              5993          2       Yes
# 1              5130          1        No
# 2              2090          2       Yes
# 3              2909          4        No
# 4              3468          1        No
# ...             ...        ...       ...
# 1465           2571          2        No
# 1466           9991          1        No
# 1467           6142          3        No
# 1468           5390          3        No
# 1469           4404          3        No
#
# [1470 rows x 3 columns]

# %%
plt.figure(figsize =(10, 9))
sns.violinplot(data=Emp_attr, y="MonthlyIncome", 
               x="Education", hue="Attrition",palette="Set2",
               slit="true").set(title = 'average monthly income by education and attrition')
# Out:
# [Text(0.5, 1.0, 'average monthly income by education and attrition')]
